# %%
import pandas as pd
from sklearn.model_selection import train_test_split

study = pd.read_csv('resource/dataset/StudentsStudyHour/Student Study Hour V2.csv')
study.head()

train, test = train_test_split(study, test_size=0.2)

x_train = train[['Hours']].to_numpy()
y_train = train[['Scores']].to_numpy()

x_test = test[['Hours']].to_numpy()
y_test = test[['Scores']].to_numpy()

# %%
study.shape
# Out:
# (28, 2)

# %%
import matplotlib.pyplot as plt

plt.scatter(x_train,y_train, label ='d')

# %%
x_train
# Out:
# array([[2.7],
#        [8.9],
#        [6.9],
#        [1.5],
#        [5.9],
#        [1.9],
#        [6.1],
#        [1.1],
#        [3.5],
#        [4.5],
#        [1.3],
#        [2.5],
#        [8.3],
#        [7.7],
#        [8.5],
#        [4.8],
#        [3.8],
#        [3.2],
#        [7.8],
#        [5.1],
#        [2.5],
#        [5.5]])

# %%
import tensorflow as tf

# w_1 = tf.Variable(tf.random.normal([1]))
# w_2 = tf.Variable(tf.random.normal([1]))
# w_3 = tf.Variable(tf.random.normal([1]))
# b = tf.Variable(tf.random.normal([1]))
x_train = [1,2,3,4]
y_train = [1,2,3,4]

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(256, input_dim= 1, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(32, activation='relu'))
model.add(tf.keras.layers.Dense(16, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='linear'))
# model.add(tf.keras.layers.Dense(1, activation='linear'))
# model.add(tf.keras.layers.Dense(1, activation='relu'))
# model.add(tf.keras.layers.Dense(1))
# model.add(tf.keras.layers.Dense(1, input_dim=1))

# %%
x_train = [1]
y_train = [2]

# %%
model.summary()
model.get_weights()
# Out:
# Model: "sequential_58"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_94 (Dense)            (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# [array([[0.50019395]], dtype=float32), array([0.], dtype=float32)]

# %%
sgd = tf.keras.optimizers.SGD(learning_rate=0.0001)
model.compile(loss='mse',optimizer=sgd,metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=3000,verbose=1,batch_size=32)
# Out:
# Epoch 1/3000
# 1/1 [==============================] - 0s 377ms/step - loss: 7.4607e-14 - accuracy: 0.2500
# Epoch 2/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4607e-14 - accuracy: 0.2500
# Epoch 3/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4607e-14 - accuracy: 0.2500
# Epoch 4/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4607e-14 - accuracy: 0.2500
# Epoch 5/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4607e-14 - accuracy: 0.2500
# Epoch 6/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4607e-14 - accuracy: 0.2500
# Epoch 7/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4607e-14 - accuracy: 0.2500
# Epoch 8/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4607e-14 - accuracy: 0.2500
# Epoch 9/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 7.4607e-14 - accuracy: 0.2500
# Epoch 10/3000
# ...

# %%
model.get_weights()
# Out:
# [array([[-0.17521165, -0.16719677, -0.07772972,  0.17271096,  0.14057343,
#           0.14041308, -0.03246775,  0.05902879,  0.17554092, -0.13429077,
#           0.10787852,  0.01873938, -0.06363241, -0.18115169, -0.13546127,
#          -0.20159411,  0.17654198, -0.07495686,  0.15597293,  0.16550457,
#          -0.00107604,  0.03357761,  0.16541368, -0.14536166, -0.13284642,
#          -0.0030534 , -0.19065772,  0.01450105, -0.02310488,  0.02696731,
#           0.21544696,  0.09680533, -0.0963045 ,  0.15595505, -0.05726404,
#           0.03931655, -0.00365154,  0.17307848,  0.20164312,  0.01213252,
#          -0.03917219, -0.03063236, -0.13798247,  0.13079946, -0.19697398,
#           0.08761533, -0.02366756,  0.1020715 ,  0.03298244,  0.13943022,
#           0.03851637, -0.13974155, -0.195046  ,  0.06210123, -0.10351566,
#           0.11112306,  0.0058418 , -0.08006808,  0.10186262,  0.11930288,
#           0.1263211 ,  0.18169561, -0.06540677, -0.02568877, -0.09308723,
# ...

# %%
# testM.get_weights()
loss, acc = model.evaluate(x_test, y_test, batch_size=1)
# testM.predict([2.5])
# testM.summary()
# Out:
# 6/6 [==============================] - 0s 1ms/step - loss: 49.9919 - accuracy: 0.0000e+00

# %%
x_test = [11,24,33,54]
model.predict(x_test)
# Out:
# array([[10.958023],
#        [23.865248],
#        [32.799206],
#        [53.64512 ]], dtype=float32)
